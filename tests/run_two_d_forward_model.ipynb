# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from codes import TwoDDzForwardModel
import numpy as np

model = TwoDDzForwardModel()
model = model.build_uniform_patches(12, 12000.)
model = model.gen_triangular_slip_distribution()
xs = np.linspace(-10000, 10000, 500)
model = model.run(xs)
model = model.add_gaussian_noise()

model.plot()
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  array([<Axes: xlabel='Slip (m)', ylabel='Depth (m)'>,
#         <Axes: xlabel='Displacement from fault (m)', ylabel='Vertical displacement (m)'>],
#        dtype=object))
