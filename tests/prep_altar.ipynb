# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
####    PATHS AND DIRECTORIES    ####
from os import path
main_dir = "/Users/hintont/Dev/projects/Ridgecrest"
insar_dir = path.join(main_dir, "data/insar")
insar_names = ["A064_20190704-0710", "D071_20190704-0716"]
gnss_dir = path.join(main_dir, "data/gnss")
gnss_filenames = ["unr_gps_offsets_full.txt"]
fault_dir = path.join(main_dir, "data/faults")
fault_filenames = ["fault1.mesh.triangles", "fault3.mesh.triangles"]
